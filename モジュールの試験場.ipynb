# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/My Drive/Pipeline")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import importlib
importlib.reload(tameshi1)
import tameshi1

# %%
tameshi1.run()
# Out:
# 2020-09-24 22:00:20,712 - INFO - logger set up
# 2020-09-24 22:00:20,716 - INFO - log:fruits
# ログセットアップ、ログファイルの生成
# fruits apple
# 'fruits'

# %%
from tqdm import tqdm

# %%
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
aa = tqdm(range(10000),position=0)
for i in aa:
  j = i*i
  aa.set_description("unchi{}".format(i))
# Out:
# ...
# unchi9999: 100%|██████████| 10000/10000 [00:12<00:00, 814.66it/s]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\Google ドライブ\Pipeline\_data\plant-pathology\predict_plant_pathology.csv")

# %%
# %load_ext autoreload

# %autoreload 2
import importlib

import plotting
importlib.reload(plotting.plot_confusion)
from plotting.plot_confusion import plot_confusion_matrix

# %%
df = df.iloc[:,1:]
df_numpy=df.to_numpy()
df_numpy
# Out:
# array([[6.79e-04, 1.87e-01, 9.99e+01, 4.45e-04],
#        [4.63e-03, 7.59e-02, 9.99e+01, 1.26e-03],
#        [5.43e-05, 1.27e-03, 1.38e-05, 7.70e+01],
#        ...,
#        [4.36e-03, 4.24e-02, 9.99e+01, 1.51e-04],
#        [7.69e+01, 2.46e-02, 3.44e-03, 1.66e-02],
#        [1.33e-03, 7.75e-02, 2.45e-04, 7.69e+01]])

# %%
df
# Out:
#         healthy  multiple_diseases       rust       scab
# 0      0.000679           0.187000  99.900000   0.000445
# 1      0.004630           0.075900  99.900000   0.001260
# 2      0.000054           0.001270   0.000014  77.000000
# 3     77.000000           0.000562   0.010600   0.004520
# 4      0.000879           0.064500  99.900000   0.001170
# ...         ...                ...        ...        ...
# 1816   0.001370           0.035700  99.900000   0.001720
# 1817   0.120000           1.480000   0.006320  75.400000
# 1818   0.004360           0.042400  99.900000   0.000151
# 1819  76.900000           0.024600   0.003440   0.016600
# 1820   0.001330           0.077500   0.000245  76.900000
#
# [1821 rows x 4 columns]

# %%
plot_confusion_matrix(df_numpy,df_numpy,df,df)
