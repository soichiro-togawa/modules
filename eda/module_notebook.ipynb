# %% [markdown]
# # モジュール実行用

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys,importlib
sys.path.append("/content/drive/My Drive/Pipeline")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #importでの実行

# %%
#load&reload
import eda
importlib.reload(eda)
from eda import *

# %%
dir = "/content"
df_train = eda_read_csv.read_csv()
# Out:
# 初期化

# %%
import eda
importlib.reload(eda)
from eda import

# %%
from eda import read_csv
# Out:
# 初期化
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-ee4dbfc8eac8> in <module>()
# ----> 1 from eda import read_csv
#
# ImportError: cannot import name 'read_csv'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# # .pyでの実行
